# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\René\Desktop\WBS-Project 4\df_audio_features_10.csv", index_col=["song_name", "artist", "id", "html"])
df
# Out:
#                                                                                                                                                    danceability  \
# song_name                                          artist               id                     html
# My Band                                            D12                  4XHQyvbrBsQaaBUW1VvmsL https://open.spotify.com/track/4XHQyvbrBsQaaBUW...         0.851
# The Real Slim Shady                                Eminem               3yfqSUWxFvZELEM4PmlwIR https://open.spotify.com/track/3yfqSUWxFvZELEM4...         0.949
# Águas De Março                                     Antônio Carlos Jobim 1y7OxO5i6sfrHXAmUM77YG https://open.spotify.com/track/1y7OxO5i6sfrHXAm...         0.642
# The Girl From Ipanema                              Stan Getz            3898C4AbdbptwYet6547e5 https://open.spotify.com/track/3898C4AbdbptwYet...         0.641
# ...

# %% [markdown]
# Some of the data is on a significantly larger scale, which can have a massive impact on measuring distances.
# Loudness ranges from -33 to 0, whereas energy ranges from 0 to 1. This means that a 10% increase in loudness will produce a distance of 3.3, and a 10% increase in energy will only produce a distance of 0.1.
# As we use distance to calculate similarity, our model will be very sensitive to changes in loudness, but not in energy.
# To correct this we scale our data, so that everything fits within the same range, meaning that a 10% increase in loudness will affect our distances the same as a 10% increase in energy.
# To scale our data we will transform it using Scikit-Learn.

# %%
# 1. import the transformer
from sklearn.preprocessing import MinMaxScaler
 
# 2. initialize the transformer (optionally, set parameters)
my_min_max = MinMaxScaler(feature_range=(0,1))
 
# 3. fit the transformer to the data
my_min_max.fit(df)
 
# 4. use the transformer to transform the data
scaled_audio_features = my_min_max.transform(df)
 
# 5. reconvert the transformed data back to a DataFrame
pd.DataFrame(scaled_audio_features,
             index=df.index,
             columns=df.columns)
# Out:
#                                                                                                                                                    danceability  \
# song_name                                          artist               id                     html
# My Band                                            D12                  4XHQyvbrBsQaaBUW1VvmsL https://open.spotify.com/track/4XHQyvbrBsQaaBUW...      0.871895
# The Real Slim Shady                                Eminem               3yfqSUWxFvZELEM4PmlwIR https://open.spotify.com/track/3yfqSUWxFvZELEM4...      1.000000
# Águas De Março                                     Antônio Carlos Jobim 1y7OxO5i6sfrHXAmUM77YG https://open.spotify.com/track/1y7OxO5i6sfrHXAm...      0.598693
# The Girl From Ipanema                              Stan Getz            3898C4AbdbptwYet6547e5 https://open.spotify.com/track/3898C4AbdbptwYet...      0.597386
# ...
